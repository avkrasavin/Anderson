# %%
import H_bose

# %%
H = H_bose.hamiltonian(6,15,3)
# Out:
# 100% |########################################################################|

# %%
H.shape
# Out:
# (4096L, 4096L)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(10,10))
plt.imshow(H)
plt.colorbar()
